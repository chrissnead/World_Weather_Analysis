# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import random
import requests
import time
from datetime import datetime
from citipy import citipy
from config import weather_api_key

# %%
# Step 1. Create a new set of 2000 random latitudes and longitudes.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-90.000, 90.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Step 2. Get the nearest city using the citipy module.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Step 3. Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Step 4. Retrieve data from the API call
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | alto araguaia
# Processing Record 4 of Set 1 | inirida
# Processing Record 5 of Set 1 | pithora
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | nicoya
# Processing Record 8 of Set 1 | itarema
# Processing Record 9 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 12 of Set 1 | cayenne
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | bakel
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | baft
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | bambous virieux
# Processing Record 19 of Set 1 | talnakh
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | mugumu
# Processing Record 22 of Set 1 | dharchula
# Processing Record 23 of Set 1 | phalaborwa
# Processing Record 24 of Set 1 | rio gallegos
# Processing Record 25 of Set 1 | somerset east
# Processing Record 26 of Set 1 | khanpur
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | saint anthony
# Processing Record 29 of Set 1 | lagoa
# Processing Record 30 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 1 | maku
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | natal
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | moussoro
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | balsas
# Processing Record 43 of Set 1 | awbari
# Processing Record 44 of Set 1 | mirwah
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | kayerkan
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | kavaratti
# Processing Record 50 of Set 1 | chebenki
# Processing Record 1 of Set 2 | saldanha
# Processing Record 2 of Set 2 | xuddur
# Processing Record 3 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | mayumba
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | klaksvik
# Processing Record 8 of Set 2 | vila franca do campo
# Processing Record 9 of Set 2 | ambilobe
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | camocim
# Processing Record 12 of Set 2 | buraydah
# Processing Record 13 of Set 2 | srivardhan
# Processing Record 14 of Set 2 | ariano irpino
# Processing Record 15 of Set 2 | mastic beach
# Processing Record 16 of Set 2 | inta
# Processing Record 17 of Set 2 | cap malheureux
# Processing Record 18 of Set 2 | sur
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | eyrarbakki
# Processing Record 21 of Set 2 | arkhangelos
# City not found. Skipping...
# Processing Record 22 of Set 2 | chapais
# Processing Record 23 of Set 2 | aranos
# Processing Record 24 of Set 2 | berlevag
# Processing Record 25 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 2 | pionki
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 2 | kushmurun
# Processing Record 30 of Set 2 | henties bay
# Processing Record 31 of Set 2 | presidente medici
# Processing Record 32 of Set 2 | souillac
# Processing Record 33 of Set 2 | othonoi
# City not found. Skipping...
# Processing Record 34 of Set 2 | tazovskiy
# Processing Record 35 of Set 2 | belmonte
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | yar-sale
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | zhashkiv
# Processing Record 41 of Set 2 | muros
# Processing Record 42 of Set 2 | marzuq
# Processing Record 43 of Set 2 | jalu
# Processing Record 44 of Set 2 | arlit
# Processing Record 45 of Set 2 | coquimbo
# Processing Record 46 of Set 2 | longyearbyen
# Processing Record 47 of Set 2 | mashhad
# Processing Record 48 of Set 2 | quelimane
# Processing Record 49 of Set 2 | chateauroux
# Processing Record 50 of Set 2 | maracacume
# Processing Record 1 of Set 3 | san ignacio
# Processing Record 2 of Set 3 | nyborg
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | saint george
# Processing Record 5 of Set 3 | hofn
# Processing Record 6 of Set 3 | ponnani
# Processing Record 7 of Set 3 | jujuy
# City not found. Skipping...
# Processing Record 8 of Set 3 | lowestoft
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | iskateley
# Processing Record 11 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 13 of Set 3 | ribeira grande
# Processing Record 14 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 15 of Set 3 | westport
# Processing Record 16 of Set 3 | namibe
# Processing Record 17 of Set 3 | margate
# Processing Record 18 of Set 3 | hambantota
# Processing Record 19 of Set 3 | grand gaube
# Processing Record 20 of Set 3 | abu samrah
# Processing Record 21 of Set 3 | rawah
# Processing Record 22 of Set 3 | illela
# Processing Record 23 of Set 3 | pirogovo
# Processing Record 24 of Set 3 | faya
# Processing Record 25 of Set 3 | plettenberg bay
# Processing Record 26 of Set 3 | almeirim
# Processing Record 27 of Set 3 | remanso
# Processing Record 28 of Set 3 | anjozorobe
# Processing Record 29 of Set 3 | guajara-mirim
# City not found. Skipping...
# Processing Record 30 of Set 3 | araucaria
# Processing Record 31 of Set 3 | carutapera
# Processing Record 32 of Set 3 | am timan
# Processing Record 33 of Set 3 | cidreira
# Processing Record 34 of Set 3 | salinopolis
# Processing Record 35 of Set 3 | samarkand
# Processing Record 36 of Set 3 | gat
# Processing Record 37 of Set 3 | san joaquin
# Processing Record 38 of Set 3 | nurota
# Processing Record 39 of Set 3 | trairi
# Processing Record 40 of Set 3 | pimentel
# Processing Record 41 of Set 3 | pisco
# Processing Record 42 of Set 3 | saint-pierre
# Processing Record 43 of Set 3 | ostrov
# Processing Record 44 of Set 3 | benguela
# Processing Record 45 of Set 3 | cierna nad tisou
# Processing Record 46 of Set 3 | xique-xique
# Processing Record 47 of Set 3 | tarko-sale
# Processing Record 48 of Set 3 | marquette
# Processing Record 49 of Set 3 | pomorie
# Processing Record 50 of Set 3 | mahebourg
# Processing Record 1 of Set 4 | saint-denis
# Processing Record 2 of Set 4 | benidorm
# Processing Record 3 of Set 4 | subtanjalla
# Processing Record 4 of Set 4 | caravelas
# Processing Record 5 of Set 4 | bestobe
# Processing Record 6 of Set 4 | kedrovyy
# Processing Record 7 of Set 4 | hamilton
# Processing Record 8 of Set 4 | rajampet
# Processing Record 9 of Set 4 | mancio lima
# Processing Record 10 of Set 4 | sakakah
# Processing Record 11 of Set 4 | nadym
# Processing Record 12 of Set 4 | sidi ali
# Processing Record 13 of Set 4 | wagar
# Processing Record 14 of Set 4 | itaueira
# Processing Record 15 of Set 4 | sayyan
# Processing Record 16 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 4 | kalmunai
# Processing Record 18 of Set 4 | uchaly
# Processing Record 19 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 4 | mubende
# Processing Record 21 of Set 4 | hit
# Processing Record 22 of Set 4 | peranamallur
# Processing Record 23 of Set 4 | codrington
# Processing Record 24 of Set 4 | tornio
# Processing Record 25 of Set 4 | mbandaka
# Processing Record 26 of Set 4 | concarneau
# Processing Record 27 of Set 4 | matagami
# Processing Record 28 of Set 4 | chapada dos guimaraes
# Processing Record 29 of Set 4 | victoria
# Processing Record 30 of Set 4 | perieti
# Processing Record 31 of Set 4 | husavik
# Processing Record 32 of Set 4 | nawabshah
# Processing Record 33 of Set 4 | alakurtti
# Processing Record 34 of Set 4 | rawson
# Processing Record 35 of Set 4 | urumqi
# Processing Record 36 of Set 4 | ngama
# Processing Record 37 of Set 4 | ellsworth
# Processing Record 38 of Set 4 | salalah
# Processing Record 39 of Set 4 | goure
# Processing Record 40 of Set 4 | karasburg
# Processing Record 41 of Set 4 | quatre cocos
# Processing Record 42 of Set 4 | copiapo
# Processing Record 43 of Set 4 | matara
# Processing Record 44 of Set 4 | bonavista
# Processing Record 45 of Set 4 | oistins
# Processing Record 46 of Set 4 | clyde river
# Processing Record 47 of Set 4 | lebu
# Processing Record 48 of Set 4 | laguna
# Processing Record 49 of Set 4 | lagos
# Processing Record 50 of Set 4 | manavadar
# Processing Record 1 of Set 5 | los llanos de aridane
# Processing Record 2 of Set 5 | walvis bay
# Processing Record 3 of Set 5 | sosnovoborsk
# Processing Record 4 of Set 5 | vadso
# Processing Record 5 of Set 5 | carballo
# Processing Record 6 of Set 5 | constitucion
# Processing Record 7 of Set 5 | mahajanga
# Processing Record 8 of Set 5 | mehamn
# Processing Record 9 of Set 5 | castro
# Processing Record 10 of Set 5 | torri di quartesolo
# Processing Record 11 of Set 5 | antalaha
# Processing Record 12 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 5 | harper
# Processing Record 14 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 5 | adrar
# Processing Record 17 of Set 5 | ordu
# Processing Record 18 of Set 5 | beohari
# Processing Record 19 of Set 5 | padang
# Processing Record 20 of Set 5 | kabalo
# Processing Record 21 of Set 5 | knysna
# Processing Record 22 of Set 5 | grindavik
# Processing Record 23 of Set 5 | amapa
# Processing Record 24 of Set 5 | the valley
# Processing Record 25 of Set 5 | havre-saint-pierre
# Processing Record 26 of Set 5 | lucea
# Processing Record 27 of Set 5 | kidal
# Processing Record 28 of Set 5 | soverato
# Processing Record 29 of Set 5 | krasnoselkup
# Processing Record 30 of Set 5 | samana
# Processing Record 31 of Set 5 | vila velha
# Processing Record 32 of Set 5 | isla mujeres
# Processing Record 33 of Set 5 | nanortalik
# Processing Record 34 of Set 5 | nueva guinea
# Processing Record 35 of Set 5 | sao joao da barra
# Processing Record 36 of Set 5 | huambo
# Processing Record 37 of Set 5 | takoradi
# Processing Record 38 of Set 5 | jasidih
# Processing Record 39 of Set 5 | khairpur
# Processing Record 40 of Set 5 | san cristobal
# Processing Record 41 of Set 5 | distraccion
# Processing Record 42 of Set 5 | oxapampa
# Processing Record 43 of Set 5 | micheweni
# Processing Record 44 of Set 5 | ivanava
# Processing Record 45 of Set 5 | primero de marzo
# Processing Record 46 of Set 5 | birjand
# Processing Record 47 of Set 5 | ullapool
# Processing Record 48 of Set 5 | torbay
# Processing Record 49 of Set 5 | suluq
# Processing Record 50 of Set 5 | angoche
# Processing Record 1 of Set 6 | muhos
# Processing Record 2 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 3 of Set 6 | luanda
# Processing Record 4 of Set 6 | oktyabrskoye
# Processing Record 5 of Set 6 | hanko
# Processing Record 6 of Set 6 | harstad
# Processing Record 7 of Set 6 | aranzazu
# Processing Record 8 of Set 6 | santiago del estero
# Processing Record 9 of Set 6 | finsterwalde
# Processing Record 10 of Set 6 | batangafo
# Processing Record 11 of Set 6 | ostrovnoy
# Processing Record 12 of Set 6 | viedma
# Processing Record 13 of Set 6 | ribeira brava
# Processing Record 14 of Set 6 | tabuk
# Processing Record 15 of Set 6 | jarvakandi
# Processing Record 16 of Set 6 | mocuba
# Processing Record 17 of Set 6 | rakitnoye
# Processing Record 18 of Set 6 | borama
# City not found. Skipping...
# Processing Record 19 of Set 6 | halifax
# Processing Record 20 of Set 6 | campos belos
# Processing Record 21 of Set 6 | inhambane
# Processing Record 22 of Set 6 | sarankhola
# Processing Record 23 of Set 6 | ajdabiya
# Processing Record 24 of Set 6 | carnaiba
# Processing Record 25 of Set 6 | coihaique
# Processing Record 26 of Set 6 | mehriz
# Processing Record 27 of Set 6 | iqaluit
# Processing Record 28 of Set 6 | gashua
# Processing Record 29 of Set 6 | talawdi
# City not found. Skipping...
# Processing Record 30 of Set 6 | murmashi
# Processing Record 31 of Set 6 | narsaq
# Processing Record 32 of Set 6 | kargopol
# Processing Record 33 of Set 6 | atar
# Processing Record 34 of Set 6 | fomboni
# Processing Record 35 of Set 6 | mineros
# Processing Record 36 of Set 6 | doha
# Processing Record 37 of Set 6 | desbiens
# Processing Record 38 of Set 6 | sao geraldo do araguaia
# Processing Record 39 of Set 6 | kromy
# Processing Record 40 of Set 6 | olafsvik
# Processing Record 41 of Set 6 | tres lagoas
# Processing Record 42 of Set 6 | dakar
# Processing Record 43 of Set 6 | neyvo-shaytanskiy
# Processing Record 44 of Set 6 | lahij
# Processing Record 45 of Set 6 | parga
# Processing Record 46 of Set 6 | aasiaat
# Processing Record 47 of Set 6 | inyonga
# Processing Record 48 of Set 6 | dingle
# Processing Record 49 of Set 6 | karasjok
# Processing Record 50 of Set 6 | monroe
# Processing Record 1 of Set 7 | valenca
# Processing Record 2 of Set 7 | igurubi
# Processing Record 3 of Set 7 | rio cuarto
# Processing Record 4 of Set 7 | pangnirtung
# Processing Record 5 of Set 7 | jaque
# Processing Record 6 of Set 7 | cadillac
# Processing Record 7 of Set 7 | manta
# Processing Record 8 of Set 7 | qaqortoq
# Processing Record 9 of Set 7 | ostersund
# Processing Record 10 of Set 7 | aksay
# Processing Record 11 of Set 7 | toropets
# Processing Record 12 of Set 7 | vardo
# Processing Record 13 of Set 7 | hagerstown
# Processing Record 14 of Set 7 | kobylka
# Processing Record 15 of Set 7 | godhra
# Processing Record 16 of Set 7 | praia
# Processing Record 17 of Set 7 | bengkulu
# Processing Record 18 of Set 7 | port-gentil
# Processing Record 19 of Set 7 | culpeper
# Processing Record 20 of Set 7 | sisimiut
# Processing Record 21 of Set 7 | zhezkazgan
# Processing Record 22 of Set 7 | krotoszyn
# Processing Record 23 of Set 7 | long mountain
# Processing Record 24 of Set 7 | pecanha
# Processing Record 25 of Set 7 | qrendi
# Processing Record 26 of Set 7 | dulovo
# Processing Record 27 of Set 7 | ormara
# Processing Record 28 of Set 7 | carnarvon
# Processing Record 29 of Set 7 | yanaul
# Processing Record 30 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 7 | rocha
# Processing Record 32 of Set 7 | shu
# Processing Record 33 of Set 7 | kharan
# Processing Record 34 of Set 7 | bastia
# Processing Record 35 of Set 7 | cordoba
# Processing Record 36 of Set 7 | lazdijai
# Processing Record 37 of Set 7 | chisindia
# Processing Record 38 of Set 7 | altamira
# Processing Record 39 of Set 7 | touros
# Processing Record 40 of Set 7 | tarabuco
# Processing Record 41 of Set 7 | igarka
# Processing Record 42 of Set 7 | korla
# Processing Record 43 of Set 7 | kovdor
# Processing Record 44 of Set 7 | troitskoye
# Processing Record 45 of Set 7 | yenagoa
# Processing Record 46 of Set 7 | san rafael
# Processing Record 47 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 48 of Set 7 | tshane
# Processing Record 49 of Set 7 | sept-iles
# Processing Record 50 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 1 of Set 8 | marsh harbour
# Processing Record 2 of Set 8 | mogadishu
# Processing Record 3 of Set 8 | vera cruz
# Processing Record 4 of Set 8 | svetlyy
# Processing Record 5 of Set 8 | aksarka
# Processing Record 6 of Set 8 | zaraza
# Processing Record 7 of Set 8 | shelburne
# Processing Record 8 of Set 8 | komsomolskiy
# Processing Record 9 of Set 8 | lucenec
# Processing Record 10 of Set 8 | brokopondo
# Processing Record 11 of Set 8 | coracora
# Processing Record 12 of Set 8 | saint-georges
# Processing Record 13 of Set 8 | kamenka
# Processing Record 14 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 8 | changji
# Processing Record 16 of Set 8 | sintea mare
# Processing Record 17 of Set 8 | leshukonskoye
# Processing Record 18 of Set 8 | beloha
# Processing Record 19 of Set 8 | khowst
# Processing Record 20 of Set 8 | santa isabel do rio negro
# Processing Record 21 of Set 8 | nouadhibou
# Processing Record 22 of Set 8 | abalak
# Processing Record 23 of Set 8 | libreville
# Processing Record 24 of Set 8 | albany
# Processing Record 25 of Set 8 | verdalsora
# City not found. Skipping...
# Processing Record 26 of Set 8 | kourou
# Processing Record 27 of Set 8 | rio grande
# Processing Record 28 of Set 8 | pindushi
# Processing Record 29 of Set 8 | port blair
# Processing Record 30 of Set 8 | comodoro rivadavia
# Processing Record 31 of Set 8 | bull savanna
# Processing Record 32 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 8 | olinda
# Processing Record 34 of Set 8 | baghdad
# Processing Record 35 of Set 8 | camaiore
# Processing Record 36 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 8 | kontagora
# Processing Record 38 of Set 8 | jonkoping
# Processing Record 39 of Set 8 | bathsheba
# Processing Record 40 of Set 8 | ancud
# Processing Record 41 of Set 8 | rafai
# Processing Record 42 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 8 | sao filipe
# Processing Record 44 of Set 8 | aswan
# Processing Record 45 of Set 8 | huallanca
# Processing Record 46 of Set 8 | bud
# Processing Record 47 of Set 8 | porbandar
# Processing Record 48 of Set 8 | verkhnyaya inta
# Processing Record 49 of Set 8 | la chaux-de-fonds
# Processing Record 50 of Set 8 | burgersdorp
# Processing Record 1 of Set 9 | sayan
# Processing Record 2 of Set 9 | neuquen
# Processing Record 3 of Set 9 | bourbonnais
# Processing Record 4 of Set 9 | guider
# Processing Record 5 of Set 9 | bunol
# Processing Record 6 of Set 9 | jutai
# Processing Record 7 of Set 9 | gewane
# Processing Record 8 of Set 9 | buzmeyin
# Processing Record 9 of Set 9 | hosangadi
# Processing Record 10 of Set 9 | kirkuk
# Processing Record 11 of Set 9 | lima
# Processing Record 12 of Set 9 | maldonado
# Processing Record 13 of Set 9 | waddan
# Processing Record 14 of Set 9 | akhtanizovskaya
# Processing Record 15 of Set 9 | malindi
# Processing Record 16 of Set 9 | povenets
# Processing Record 17 of Set 9 | mayahi
# Processing Record 18 of Set 9 | abonnema
# Processing Record 19 of Set 9 | alpena
# Processing Record 20 of Set 9 | axim
# Processing Record 21 of Set 9 | camana
# Processing Record 22 of Set 9 | ios
# Processing Record 23 of Set 9 | puerto del rosario
# Processing Record 24 of Set 9 | chiredzi
# Processing Record 25 of Set 9 | marica
# Processing Record 26 of Set 9 | temir
# Processing Record 27 of Set 9 | taoudenni
# Processing Record 28 of Set 9 | villa carlos paz
# Processing Record 29 of Set 9 | mgandu
# Processing Record 30 of Set 9 | willowmore
# Processing Record 31 of Set 9 | adre
# Processing Record 32 of Set 9 | wieliczka
# Processing Record 33 of Set 9 | pointe michel
# Processing Record 34 of Set 9 | imbituba
# Processing Record 35 of Set 9 | mantua
# Processing Record 36 of Set 9 | thaba-tseka
# Processing Record 37 of Set 9 | manali
# Processing Record 38 of Set 9 | alanya
# Processing Record 39 of Set 9 | sirjan
# Processing Record 40 of Set 9 | gavrilovka vtoraya
# Processing Record 41 of Set 9 | edgewater
# Processing Record 42 of Set 9 | atlantic city
# Processing Record 43 of Set 9 | urengoy
# Processing Record 44 of Set 9 | ungheni
# Processing Record 45 of Set 9 | tocopilla
# Processing Record 46 of Set 9 | gidam
# Processing Record 47 of Set 9 | marrakesh
# Processing Record 48 of Set 9 | harindanga
# Processing Record 49 of Set 9 | coihueco
# Processing Record 50 of Set 9 | vestmannaeyjar
# Processing Record 1 of Set 10 | itaituba
# Processing Record 2 of Set 10 | marienburg
# Processing Record 3 of Set 10 | goderich
# Processing Record 4 of Set 10 | swellendam
# Processing Record 5 of Set 10 | sorland
# Processing Record 6 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 7 of Set 10 | skibotn
# Processing Record 8 of Set 10 | borkenes
# Processing Record 9 of Set 10 | nuuk
# Processing Record 10 of Set 10 | nioro
# Processing Record 11 of Set 10 | shache
# Processing Record 12 of Set 10 | ciudad bolivar
# Processing Record 13 of Set 10 | magugu
# Processing Record 14 of Set 10 | elat
# Processing Record 15 of Set 10 | peyima
# Processing Record 16 of Set 10 | taltal
# Processing Record 17 of Set 10 | tombouctou
# Processing Record 18 of Set 10 | reconquista
# Processing Record 19 of Set 10 | carbonia
# Processing Record 20 of Set 10 | araouane
# Processing Record 21 of Set 10 | usak
# Processing Record 22 of Set 10 | nador
# Processing Record 23 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 10 | subaytilah
# City not found. Skipping...
# Processing Record 25 of Set 10 | aktash
# Processing Record 26 of Set 10 | kehtna
# Processing Record 27 of Set 10 | cururupu
# Processing Record 28 of Set 10 | bara
# Processing Record 29 of Set 10 | bouca
# Processing Record 30 of Set 10 | sao gabriel da cachoeira
# Processing Record 31 of Set 10 | omboue
# Processing Record 32 of Set 10 | kholm-zhirkovskiy
# Processing Record 33 of Set 10 | acarau
# Processing Record 34 of Set 10 | kibondo
# Processing Record 35 of Set 10 | aksu
# Processing Record 36 of Set 10 | maniitsoq
# Processing Record 37 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 10 | soavinandriana
# Processing Record 39 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 40 of Set 10 | fairhope
# Processing Record 41 of Set 10 | asheboro
# Processing Record 42 of Set 10 | alindao
# Processing Record 43 of Set 10 | maceio
# Processing Record 44 of Set 10 | zhiletovo
# Processing Record 45 of Set 10 | koulikoro
# Processing Record 46 of Set 10 | saint-alexandre
# Processing Record 47 of Set 10 | wolmaranstad
# City not found. Skipping...
# Processing Record 48 of Set 10 | pervomayskoye
# Processing Record 49 of Set 10 | malm
# Processing Record 50 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 1 of Set 11 | molina
# Processing Record 2 of Set 11 | mahon
# Processing Record 3 of Set 11 | necochea
# Processing Record 4 of Set 11 | sao lourenco
# Processing Record 5 of Set 11 | monte alegre
# Processing Record 6 of Set 11 | kaminskiy
# Processing Record 7 of Set 11 | road town
# Processing Record 8 of Set 11 | presidencia roque saenz pena
# Processing Record 9 of Set 11 | estelle
# Processing Record 10 of Set 11 | dabakala
# Processing Record 11 of Set 11 | macedo de cavaleiros
# Processing Record 12 of Set 11 | kiruna
# Processing Record 13 of Set 11 | santiago de cuba
# Processing Record 14 of Set 11 | fatehpur
# Processing Record 15 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 16 of Set 11 | sensuntepeque
# Processing Record 17 of Set 11 | port-cartier
# Processing Record 18 of Set 11 | constantine
# Processing Record 19 of Set 11 | cabrobo
# Processing Record 20 of Set 11 | paime
# Processing Record 21 of Set 11 | moose factory
# Processing Record 22 of Set 11 | abha
# Processing Record 23 of Set 11 | nantucket
# Processing Record 24 of Set 11 | navahrudak
# Processing Record 25 of Set 11 | tiznit
# Processing Record 26 of Set 11 | sanary-sur-mer
# Processing Record 27 of Set 11 | revda
# Processing Record 28 of Set 11 | camapua
# Processing Record 29 of Set 11 | jumla
# Processing Record 30 of Set 11 | kasangulu
# Processing Record 31 of Set 11 | kudahuvadhoo
# Processing Record 32 of Set 11 | ayorou
# Processing Record 33 of Set 11 | muana
# Processing Record 34 of Set 11 | santo andre
# Processing Record 35 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 36 of Set 11 | tessalit
# Processing Record 37 of Set 11 | breytovo
# Processing Record 38 of Set 11 | riyadh
# Processing Record 39 of Set 11 | bentiu
# Processing Record 40 of Set 11 | nikel
# Processing Record 41 of Set 11 | pangoa
# Processing Record 42 of Set 11 | thinadhoo
# Processing Record 43 of Set 11 | middelburg
# Processing Record 44 of Set 11 | pitimbu
# Processing Record 45 of Set 11 | maniwaki
# Processing Record 46 of Set 11 | ventspils
# Processing Record 47 of Set 11 | bondo
# Processing Record 48 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 11 | paamiut
# Processing Record 50 of Set 11 | zelenogorskiy
# Processing Record 1 of Set 12 | fort-de-france
# Processing Record 2 of Set 12 | salta
# Processing Record 3 of Set 12 | narowal
# Processing Record 4 of Set 12 | santa maria
# Processing Record 5 of Set 12 | vetlanda
# Processing Record 6 of Set 12 | dawlatabad
# Processing Record 7 of Set 12 | tomar do geru
# Processing Record 8 of Set 12 | teguise
# Processing Record 9 of Set 12 | bandarbeyla
# Processing Record 10 of Set 12 | concordia
# Processing Record 11 of Set 12 | brae
# Processing Record 12 of Set 12 | zhovkva
# Processing Record 13 of Set 12 | yellandu
# Processing Record 14 of Set 12 | mont-de-marsan
# Processing Record 15 of Set 12 | palora
# Processing Record 16 of Set 12 | urucara
# Processing Record 17 of Set 12 | beyneu
# Processing Record 18 of Set 12 | najran
# Processing Record 19 of Set 12 | keetmanshoop
# Processing Record 20 of Set 12 | almaty
# Processing Record 21 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 22 of Set 12 | beira
# Processing Record 23 of Set 12 | paita
# Processing Record 24 of Set 12 | nizhniy baskunchak
# Processing Record 25 of Set 12 | bivolari
# Processing Record 26 of Set 12 | onega
# Processing Record 27 of Set 12 | visby
# Processing Record 28 of Set 12 | gayeri
# Processing Record 29 of Set 12 | birecik
# Processing Record 30 of Set 12 | lakkion
# Processing Record 31 of Set 12 | mumford
# Processing Record 32 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 12 | msanga
# Processing Record 34 of Set 12 | pemba
# Processing Record 35 of Set 12 | arraias
# Processing Record 36 of Set 12 | masuguru
# Processing Record 37 of Set 12 | sechura
# Processing Record 38 of Set 12 | dimitrovgrad
# Processing Record 39 of Set 12 | mtwara
# Processing Record 40 of Set 12 | pathardi
# Processing Record 41 of Set 12 | miranda
# Processing Record 42 of Set 12 | coari
# Processing Record 43 of Set 12 | lerwick
# Processing Record 44 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 45 of Set 12 | guanica
# Processing Record 46 of Set 12 | kangaatsiaq
# Processing Record 47 of Set 12 | meridian
# Processing Record 48 of Set 12 | sao felix do xingu
# Processing Record 49 of Set 12 | timra
# Processing Record 50 of Set 12 | kirovskiy
# Processing Record 1 of Set 13 | gualaquiza
# Processing Record 2 of Set 13 | penarroya-pueblonuevo
# Processing Record 3 of Set 13 | hashtrud
# Processing Record 4 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 5 of Set 13 | camacha
# Processing Record 6 of Set 13 | kisanga
# Processing Record 7 of Set 13 | puerto narino
# Processing Record 8 of Set 13 | shamary
# Processing Record 9 of Set 13 | polovinnoye
# Processing Record 10 of Set 13 | buchanan
# Processing Record 11 of Set 13 | plouzane
# Processing Record 12 of Set 13 | gimbi
# Processing Record 13 of Set 13 | kutum
# Processing Record 14 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 13 | impfondo
# Processing Record 16 of Set 13 | prieska
# Processing Record 17 of Set 13 | mitsamiouli
# Processing Record 18 of Set 13 | sambava
# Processing Record 19 of Set 13 | upington
# Processing Record 20 of Set 13 | irpa irpa
# Processing Record 21 of Set 13 | ust-tsilma
# Processing Record 22 of Set 13 | porto novo
# Processing Record 23 of Set 13 | clarence town
# Processing Record 24 of Set 13 | garowe
# Processing Record 25 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 26 of Set 13 | yefimovskiy
# City not found. Skipping...
# Processing Record 27 of Set 13 | disna
# Processing Record 28 of Set 13 | lipovat
# Processing Record 29 of Set 13 | alta floresta
# Processing Record 30 of Set 13 | bosaso
# Processing Record 31 of Set 13 | kilindoni
# Processing Record 32 of Set 13 | senanga
# Processing Record 33 of Set 13 | gubkinskiy
# Processing Record 34 of Set 13 | muzaffarpur
# Processing Record 35 of Set 13 | pitanga
# Processing Record 36 of Set 13 | saryozek
# Processing Record 37 of Set 13 | maragogi
# Processing Record 38 of Set 13 | cockburn town
# Processing Record 39 of Set 13 | ilhabela
# Processing Record 40 of Set 13 | safaga
# Processing Record 41 of Set 13 | ordynskoye
# Processing Record 42 of Set 13 | havoysund
# Processing Record 43 of Set 13 | manicore
# Processing Record 44 of Set 13 | ulagan
# Processing Record 45 of Set 13 | arys
# Processing Record 46 of Set 13 | rajshahi
# Processing Record 47 of Set 13 | rambha
# Processing Record 48 of Set 13 | montauban
# Processing Record 49 of Set 13 | saint-joseph
# Processing Record 50 of Set 13 | nkhata bay
# Processing Record 1 of Set 14 | koluszki
# Processing Record 2 of Set 14 | hochdorf
# Processing Record 3 of Set 14 | polunochnoye
# Processing Record 4 of Set 14 | sainte-maxime
# Processing Record 5 of Set 14 | puerto leguizamo
# Processing Record 6 of Set 14 | vibo valentia
# Processing Record 7 of Set 14 | ji-parana
# City not found. Skipping...
# Processing Record 8 of Set 14 | nikolskoye
# Processing Record 9 of Set 14 | kolosovka
# Processing Record 10 of Set 14 | nordfjordeid
# Processing Record 11 of Set 14 | huarmey
# Processing Record 12 of Set 14 | lamu
# Processing Record 13 of Set 14 | rundu
# Processing Record 14 of Set 14 | lipari
# Processing Record 15 of Set 14 | praia da vitoria
# Processing Record 16 of Set 14 | borsele
# Processing Record 17 of Set 14 | andenes
# Processing Record 18 of Set 14 | destin
# Processing Record 19 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 14 | canico
# Processing Record 21 of Set 14 | skegness
# Processing Record 22 of Set 14 | masallatah
# Processing Record 23 of Set 14 | dodola
# Processing Record 24 of Set 14 | tazmalt
# Processing Record 25 of Set 14 | denau
# City not found. Skipping...
# Processing Record 26 of Set 14 | calderitas
# Processing Record 27 of Set 14 | biltine
# Processing Record 28 of Set 14 | marovoay
# Processing Record 29 of Set 14 | allada
# Processing Record 30 of Set 14 | mandera
# Processing Record 31 of Set 14 | bella union
# Processing Record 32 of Set 14 | shumikha
# Processing Record 33 of Set 14 | roald
# Processing Record 34 of Set 14 | puyo
# Processing Record 35 of Set 14 | ishim
# Processing Record 36 of Set 14 | tondon
# Processing Record 37 of Set 14 | itacare
# Processing Record 38 of Set 14 | kassala
# Processing Record 39 of Set 14 | parry sound
# Processing Record 40 of Set 14 | upata
# Processing Record 41 of Set 14 | kalemie
# Processing Record 42 of Set 14 | osvaldo cruz
# Processing Record 43 of Set 14 | gamba
# Processing Record 44 of Set 14 | brandfort
# Processing Record 45 of Set 14 | pokhara
# Processing Record 46 of Set 14 | jadu
# Processing Record 47 of Set 14 | santa cruz
# Processing Record 48 of Set 14 | norden
# Processing Record 49 of Set 14 | a
# City not found. Skipping...
# Processing Record 50 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 1 of Set 15 | puerto ayacucho
# Processing Record 2 of Set 15 | menongue
# Processing Record 3 of Set 15 | warmbad
# Processing Record 4 of Set 15 | kannur
# Processing Record 5 of Set 15 | sjovegan
# Processing Record 6 of Set 15 | petukhovo
# Processing Record 7 of Set 15 | bafq
# Processing Record 8 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 9 of Set 15 | kapuskasing
# Processing Record 10 of Set 15 | tsienyane
# City not found. Skipping...
# Processing Record 11 of Set 15 | nerja
# Processing Record 12 of Set 15 | mezen
# Processing Record 13 of Set 15 | saginaw
# Processing Record 14 of Set 15 | wamba
# Processing Record 15 of Set 15 | devarkonda
# Processing Record 16 of Set 15 | quimper
# Processing Record 17 of Set 15 | uaua
# Processing Record 18 of Set 15 | liverpool
# Processing Record 19 of Set 15 | togur
# Processing Record 20 of Set 15 | pospelikha
# Processing Record 21 of Set 15 | traverse city
# Processing Record 22 of Set 15 | biu
# Processing Record 23 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 15 | mul
# Processing Record 25 of Set 15 | wellington
# Processing Record 26 of Set 15 | zaysan
# Processing Record 27 of Set 15 | werda
# Processing Record 28 of Set 15 | kostomuksha
# Processing Record 29 of Set 15 | moultrie
# Processing Record 30 of Set 15 | malakisi
# City not found. Skipping...
# Processing Record 31 of Set 15 | sandy bay
# Processing Record 32 of Set 15 | canutama
# Processing Record 33 of Set 15 | chemal
# Processing Record 34 of Set 15 | jilmah
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Step 5. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.8000 -68.3000     42.46        93          75
# 1   Mar Del Plata      AR -38.0023 -57.5575     71.10        85          20
# 2   Alto Araguaia      BR -17.3147 -53.2153     67.95        98         100
# 3         Inirida      CO   3.8653 -67.9239     70.20        63          36
# 4         Pithora      IN  21.2667  82.5167     74.07        19           1
# 5  Port Elizabeth      ZA -33.9180  25.5701     70.11        72          11
# 6          Nicoya      CR  10.1483 -85.4520     78.35        77           9
# 7         Itarema      BR  -2.9248 -39.9167     75.09        87          98
# 8       Hithadhoo      MV  -0.6000  73.0833     81.54        67          75
# 9         Cayenne      GF   4.9333 -52.3333     78.10        87          40
#
#    Wind Speed Current Description
# 0        4.61       broken clouds
# 1        3.00          few clouds
# 2        7.16     overcast clouds
# 3        2.75    scattered clouds
# 4        6.06           clear sky
# 5        4.32          few clouds
# 6        6.82           clear sky
# 7        7.23          light rain
# 8        4.12       broken clouds
# 9        3.00    scattered clouds

# %%
# Step 6. Export the DataFrame as a CSV file.
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
