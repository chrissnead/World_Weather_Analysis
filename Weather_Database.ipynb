# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import random
import requests
import time
from datetime import datetime
from citipy import citipy
from config import weather_api_key

# %%
# Step 1. Create a new set of 2000 random latitudes and longitudes.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-90.000, 90.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Step 2. Get the nearest city using the citipy module.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Step 3. Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Step 4. Retrieve data from the API call
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ust-ishim
# Processing Record 2 of Set 1 | walvis bay
# Processing Record 3 of Set 1 | rocha
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | kikwit
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | umm lajj
# Processing Record 8 of Set 1 | codrington
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | nacala
# Processing Record 11 of Set 1 | caxito
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | margate
# Processing Record 14 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 1 | melito di porto salvo
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | monsenhor gil
# Processing Record 19 of Set 1 | hofn
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | farafangana
# Processing Record 22 of Set 1 | iqaluit
# Processing Record 23 of Set 1 | akdepe
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | eyrarbakki
# Processing Record 27 of Set 1 | salalah
# Processing Record 28 of Set 1 | malanje
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | kijaba
# City not found. Skipping...
# Processing Record 31 of Set 1 | juba
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | bambous virieux
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 36 of Set 1 | maun
# Processing Record 37 of Set 1 | laguna
# Processing Record 38 of Set 1 | clyde river
# Processing Record 39 of Set 1 | kerouane
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | souillac
# Processing Record 44 of Set 1 | boyuibe
# Processing Record 45 of Set 1 | narsaq
# Processing Record 46 of Set 1 | raudeberg
# Processing Record 47 of Set 1 | camopi
# Processing Record 48 of Set 1 | kemi
# Processing Record 49 of Set 1 | mehamn
# Processing Record 50 of Set 1 | lagoa
# Processing Record 1 of Set 2 | uruzgan
# Processing Record 2 of Set 2 | otanche
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | hobyo
# Processing Record 5 of Set 2 | caceres
# Processing Record 6 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | chuy
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | krasnoselkup
# Processing Record 11 of Set 2 | vardo
# Processing Record 12 of Set 2 | necochea
# Processing Record 13 of Set 2 | luderitz
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 2 | klaksvik
# Processing Record 17 of Set 2 | dingle
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | tias
# Processing Record 20 of Set 2 | hambantota
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | iquitos
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | bawku
# Processing Record 25 of Set 2 | mandera
# Processing Record 26 of Set 2 | najran
# Processing Record 27 of Set 2 | jurm
# Processing Record 28 of Set 2 | bakaly
# Processing Record 29 of Set 2 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 30 of Set 2 | bay roberts
# Processing Record 31 of Set 2 | luanda
# Processing Record 32 of Set 2 | jijiga
# Processing Record 33 of Set 2 | moose factory
# Processing Record 34 of Set 2 | thinadhoo
# Processing Record 35 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 2 | novoagansk
# Processing Record 37 of Set 2 | agadez
# Processing Record 38 of Set 2 | atar
# Processing Record 39 of Set 2 | gat
# Processing Record 40 of Set 2 | agalteca
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | kawardha
# Processing Record 43 of Set 2 | sur
# Processing Record 44 of Set 2 | bubaque
# Processing Record 45 of Set 2 | sao joao da barra
# Processing Record 46 of Set 2 | pangnirtung
# Processing Record 47 of Set 2 | los llanos de aridane
# Processing Record 48 of Set 2 | valdivia
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | lemesos
# City not found. Skipping...
# Processing Record 1 of Set 3 | kahama
# Processing Record 2 of Set 3 | mumbwa
# Processing Record 3 of Set 3 | caravelas
# Processing Record 4 of Set 3 | mitsamiouli
# Processing Record 5 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 3 | saldanha
# Processing Record 8 of Set 3 | vila velha
# Processing Record 9 of Set 3 | utinga
# Processing Record 10 of Set 3 | yanam
# Processing Record 11 of Set 3 | kibala
# Processing Record 12 of Set 3 | kemise
# Processing Record 13 of Set 3 | mecca
# Processing Record 14 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 15 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | sao filipe
# Processing Record 18 of Set 3 | dubai
# Processing Record 19 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | belmonte
# Processing Record 22 of Set 3 | gardan diwal
# City not found. Skipping...
# Processing Record 23 of Set 3 | yashkul
# Processing Record 24 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 25 of Set 3 | ginda
# Processing Record 26 of Set 3 | chicama
# Processing Record 27 of Set 3 | castro
# Processing Record 28 of Set 3 | marienburg
# Processing Record 29 of Set 3 | natal
# Processing Record 30 of Set 3 | iranshahr
# Processing Record 31 of Set 3 | dhamtari
# Processing Record 32 of Set 3 | itahari
# City not found. Skipping...
# Processing Record 33 of Set 3 | paso de carrasco
# Processing Record 34 of Set 3 | alta floresta
# Processing Record 35 of Set 3 | hauterive
# Processing Record 36 of Set 3 | eirunepe
# Processing Record 37 of Set 3 | oussouye
# Processing Record 38 of Set 3 | palma di montechiaro
# Processing Record 39 of Set 3 | florianopolis
# Processing Record 40 of Set 3 | yar-sale
# Processing Record 41 of Set 3 | karlskrona
# Processing Record 42 of Set 3 | concepcion del uruguay
# Processing Record 43 of Set 3 | camana
# Processing Record 44 of Set 3 | usinsk
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | chernolesskoye
# Processing Record 47 of Set 3 | yarada
# Processing Record 48 of Set 3 | ladario
# Processing Record 49 of Set 3 | uberlandia
# Processing Record 50 of Set 3 | nizhniy odes
# Processing Record 1 of Set 4 | touros
# Processing Record 2 of Set 4 | boende
# Processing Record 3 of Set 4 | taoudenni
# Processing Record 4 of Set 4 | matagami
# Processing Record 5 of Set 4 | musafirkhana
# Processing Record 6 of Set 4 | itarema
# Processing Record 7 of Set 4 | dudinka
# Processing Record 8 of Set 4 | suleja
# Processing Record 9 of Set 4 | itinga
# Processing Record 10 of Set 4 | angra
# City not found. Skipping...
# Processing Record 11 of Set 4 | matay
# Processing Record 12 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 13 of Set 4 | mastung
# Processing Record 14 of Set 4 | abha
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | amberieu-en-bugey
# Processing Record 17 of Set 4 | toccoa
# Processing Record 18 of Set 4 | ailigandi
# Processing Record 19 of Set 4 | weymouth
# Processing Record 20 of Set 4 | jeremoabo
# Processing Record 21 of Set 4 | beneditinos
# Processing Record 22 of Set 4 | tukrah
# Processing Record 23 of Set 4 | joao pinheiro
# Processing Record 24 of Set 4 | challapata
# Processing Record 25 of Set 4 | berlevag
# Processing Record 26 of Set 4 | longyearbyen
# Processing Record 27 of Set 4 | paita
# Processing Record 28 of Set 4 | iralaya
# Processing Record 29 of Set 4 | turtkul
# City not found. Skipping...
# Processing Record 30 of Set 4 | acopiara
# Processing Record 31 of Set 4 | aswan
# Processing Record 32 of Set 4 | qaqortoq
# Processing Record 33 of Set 4 | vila franca do campo
# Processing Record 34 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 4 | eisiskes
# Processing Record 36 of Set 4 | mungwi
# Processing Record 37 of Set 4 | colesberg
# Processing Record 38 of Set 4 | ashqelon
# Processing Record 39 of Set 4 | bengkulu
# Processing Record 40 of Set 4 | cidreira
# Processing Record 41 of Set 4 | sao francisco
# Processing Record 42 of Set 4 | husavik
# Processing Record 43 of Set 4 | joshimath
# Processing Record 44 of Set 4 | puerto narino
# Processing Record 45 of Set 4 | robertsport
# Processing Record 46 of Set 4 | ermelo
# Processing Record 47 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 4 | sechura
# Processing Record 49 of Set 4 | saint-francois
# Processing Record 50 of Set 4 | aksarka
# Processing Record 1 of Set 5 | benghazi
# Processing Record 2 of Set 5 | gravdal
# Processing Record 3 of Set 5 | ilulissat
# Processing Record 4 of Set 5 | nanortalik
# Processing Record 5 of Set 5 | trincomalee
# Processing Record 6 of Set 5 | talnakh
# Processing Record 7 of Set 5 | jacmel
# Processing Record 8 of Set 5 | faratsiho
# Processing Record 9 of Set 5 | talavera
# Processing Record 10 of Set 5 | arraial do cabo
# Processing Record 11 of Set 5 | bilma
# Processing Record 12 of Set 5 | san javier
# Processing Record 13 of Set 5 | dujuma
# City not found. Skipping...
# Processing Record 14 of Set 5 | rio gallegos
# Processing Record 15 of Set 5 | inirida
# Processing Record 16 of Set 5 | nouadhibou
# Processing Record 17 of Set 5 | olden
# Processing Record 18 of Set 5 | alipur chatha
# Processing Record 19 of Set 5 | kaniama
# Processing Record 20 of Set 5 | lukovetskiy
# Processing Record 21 of Set 5 | araouane
# Processing Record 22 of Set 5 | victoria
# Processing Record 23 of Set 5 | clarence town
# Processing Record 24 of Set 5 | cayenne
# Processing Record 25 of Set 5 | venado tuerto
# Processing Record 26 of Set 5 | lancaster
# Processing Record 27 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 5 | mancio lima
# Processing Record 29 of Set 5 | guasdualito
# Processing Record 30 of Set 5 | rudnichnyy
# Processing Record 31 of Set 5 | neuquen
# Processing Record 32 of Set 5 | inhambane
# Processing Record 33 of Set 5 | zapolyarnyy
# Processing Record 34 of Set 5 | ostrovnoy
# Processing Record 35 of Set 5 | curvelo
# Processing Record 36 of Set 5 | kirkland lake
# Processing Record 37 of Set 5 | bagotville
# Processing Record 38 of Set 5 | bandarbeyla
# Processing Record 39 of Set 5 | tres arroyos
# Processing Record 40 of Set 5 | ribeira grande
# Processing Record 41 of Set 5 | cachoeiro de itapemirim
# Processing Record 42 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 5 | tashtyp
# Processing Record 44 of Set 5 | kulhudhuffushi
# Processing Record 45 of Set 5 | shelburne
# Processing Record 46 of Set 5 | minab
# Processing Record 47 of Set 5 | dhidhdhoo
# Processing Record 48 of Set 5 | kalangala
# Processing Record 49 of Set 5 | fuerte olimpo
# Processing Record 50 of Set 5 | tsnori
# Processing Record 1 of Set 6 | malindi
# Processing Record 2 of Set 6 | maniitsoq
# Processing Record 3 of Set 6 | sauce
# Processing Record 4 of Set 6 | beyneu
# Processing Record 5 of Set 6 | kabo
# Processing Record 6 of Set 6 | jalgaon
# Processing Record 7 of Set 6 | kalmunai
# Processing Record 8 of Set 6 | saint george
# Processing Record 9 of Set 6 | cape canaveral
# Processing Record 10 of Set 6 | bardiyah
# Processing Record 11 of Set 6 | guliston
# Processing Record 12 of Set 6 | ponta delgada
# Processing Record 13 of Set 6 | lamu
# Processing Record 14 of Set 6 | svetlogorsk
# Processing Record 15 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 16 of Set 6 | nantucket
# Processing Record 17 of Set 6 | mumford
# Processing Record 18 of Set 6 | togur
# Processing Record 19 of Set 6 | saint-augustin
# Processing Record 20 of Set 6 | chapada dos guimaraes
# Processing Record 21 of Set 6 | aseri
# Processing Record 22 of Set 6 | ponta do sol
# Processing Record 23 of Set 6 | ugoofaaru
# Processing Record 24 of Set 6 | kruisfontein
# Processing Record 25 of Set 6 | wajir
# Processing Record 26 of Set 6 | abu samrah
# Processing Record 27 of Set 6 | pisco
# Processing Record 28 of Set 6 | csaszartoltes
# Processing Record 29 of Set 6 | balkhash
# Processing Record 30 of Set 6 | brae
# Processing Record 31 of Set 6 | dennery
# Processing Record 32 of Set 6 | bathsheba
# Processing Record 33 of Set 6 | youghal
# Processing Record 34 of Set 6 | mendoza
# Processing Record 35 of Set 6 | leo
# Processing Record 36 of Set 6 | vallenar
# Processing Record 37 of Set 6 | sackville
# Processing Record 38 of Set 6 | la palma
# Processing Record 39 of Set 6 | harper
# Processing Record 40 of Set 6 | santa lucia
# Processing Record 41 of Set 6 | mvangue
# Processing Record 42 of Set 6 | demirci
# Processing Record 43 of Set 6 | taloqan
# Processing Record 44 of Set 6 | guaruja
# Processing Record 45 of Set 6 | japura
# Processing Record 46 of Set 6 | rylsk
# Processing Record 47 of Set 6 | lahij
# Processing Record 48 of Set 6 | vestmannaeyjar
# Processing Record 49 of Set 6 | ikom
# Processing Record 50 of Set 6 | sept-iles
# Processing Record 1 of Set 7 | razole
# Processing Record 2 of Set 7 | zhezkazgan
# Processing Record 3 of Set 7 | monte carmelo
# Processing Record 4 of Set 7 | balad
# Processing Record 5 of Set 7 | silifke
# Processing Record 6 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 7 | parnarama
# Processing Record 8 of Set 7 | quito
# Processing Record 9 of Set 7 | catania
# Processing Record 10 of Set 7 | jardim
# Processing Record 11 of Set 7 | riyadh
# Processing Record 12 of Set 7 | eraniel
# Processing Record 13 of Set 7 | tete
# Processing Record 14 of Set 7 | rokytne
# Processing Record 15 of Set 7 | kalmar
# Processing Record 16 of Set 7 | puerto ayora
# Processing Record 17 of Set 7 | massena
# Processing Record 18 of Set 7 | carutapera
# Processing Record 19 of Set 7 | sinnamary
# Processing Record 20 of Set 7 | gerash
# Processing Record 21 of Set 7 | iskateley
# Processing Record 22 of Set 7 | buraydah
# Processing Record 23 of Set 7 | wawa
# Processing Record 24 of Set 7 | fershampenuaz
# Processing Record 25 of Set 7 | raga
# Processing Record 26 of Set 7 | pomabamba
# Processing Record 27 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 7 | puerto del rosario
# Processing Record 29 of Set 7 | uaua
# Processing Record 30 of Set 7 | vangaindrano
# Processing Record 31 of Set 7 | presidencia roque saenz pena
# Processing Record 32 of Set 7 | soyo
# Processing Record 33 of Set 7 | acari
# Processing Record 34 of Set 7 | mitu
# Processing Record 35 of Set 7 | alexandria
# Processing Record 36 of Set 7 | honningsvag
# Processing Record 37 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 38 of Set 7 | sakakah
# Processing Record 39 of Set 7 | ejido
# Processing Record 40 of Set 7 | namanyere
# Processing Record 41 of Set 7 | sokoto
# Processing Record 42 of Set 7 | yalutorovsk
# Processing Record 43 of Set 7 | bogorodsk
# Processing Record 44 of Set 7 | atocha
# Processing Record 45 of Set 7 | galle
# Processing Record 46 of Set 7 | sao pedro do piaui
# Processing Record 47 of Set 7 | skiros
# City not found. Skipping...
# Processing Record 48 of Set 7 | reconquista
# Processing Record 49 of Set 7 | jumla
# Processing Record 50 of Set 7 | macau
# Processing Record 1 of Set 8 | waddan
# Processing Record 2 of Set 8 | khromtau
# Processing Record 3 of Set 8 | doka
# Processing Record 4 of Set 8 | dangriga
# Processing Record 5 of Set 8 | baie-comeau
# Processing Record 6 of Set 8 | pirgos
# Processing Record 7 of Set 8 | arlit
# Processing Record 8 of Set 8 | kudahuvadhoo
# Processing Record 9 of Set 8 | decatur
# Processing Record 10 of Set 8 | iskitim
# Processing Record 11 of Set 8 | celle
# Processing Record 12 of Set 8 | inyonga
# Processing Record 13 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 8 | isla mujeres
# Processing Record 15 of Set 8 | avallon
# Processing Record 16 of Set 8 | bogalusa
# Processing Record 17 of Set 8 | roanoke rapids
# Processing Record 18 of Set 8 | straumen
# Processing Record 19 of Set 8 | geraldton
# Processing Record 20 of Set 8 | abrau-dyurso
# Processing Record 21 of Set 8 | lubango
# Processing Record 22 of Set 8 | umm kaddadah
# Processing Record 23 of Set 8 | hamilton
# Processing Record 24 of Set 8 | nkhotakota
# Processing Record 25 of Set 8 | pabna
# Processing Record 26 of Set 8 | salinopolis
# Processing Record 27 of Set 8 | niquero
# Processing Record 28 of Set 8 | comodoro rivadavia
# Processing Record 29 of Set 8 | porto novo
# Processing Record 30 of Set 8 | skeldon
# Processing Record 31 of Set 8 | ketou
# Processing Record 32 of Set 8 | aripuana
# Processing Record 33 of Set 8 | santiago de chuco
# Processing Record 34 of Set 8 | isiro
# Processing Record 35 of Set 8 | utete
# Processing Record 36 of Set 8 | rozhyshche
# Processing Record 37 of Set 8 | bara
# Processing Record 38 of Set 8 | olafsvik
# Processing Record 39 of Set 8 | batouri
# Processing Record 40 of Set 8 | taltal
# Processing Record 41 of Set 8 | san cristobal
# Processing Record 42 of Set 8 | dobryatino
# Processing Record 43 of Set 8 | vohibinany
# Processing Record 44 of Set 8 | spirovo
# Processing Record 45 of Set 8 | kaukauna
# Processing Record 46 of Set 8 | ouallam
# Processing Record 47 of Set 8 | lebu
# Processing Record 48 of Set 8 | saint-pierre
# Processing Record 49 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 50 of Set 8 | hualmay
# Processing Record 1 of Set 9 | acarau
# Processing Record 2 of Set 9 | pinega
# Processing Record 3 of Set 9 | amos
# Processing Record 4 of Set 9 | asyut
# Processing Record 5 of Set 9 | zaozerne
# Processing Record 6 of Set 9 | malatya
# Processing Record 7 of Set 9 | hargeysa
# Processing Record 8 of Set 9 | port hawkesbury
# Processing Record 9 of Set 9 | menongue
# Processing Record 10 of Set 9 | ous
# Processing Record 11 of Set 9 | banda aceh
# Processing Record 12 of Set 9 | areia branca
# Processing Record 13 of Set 9 | adre
# Processing Record 14 of Set 9 | dois corregos
# Processing Record 15 of Set 9 | esil
# Processing Record 16 of Set 9 | san ramon de la nueva oran
# Processing Record 17 of Set 9 | kidal
# Processing Record 18 of Set 9 | stokmarknes
# Processing Record 19 of Set 9 | buchanan
# Processing Record 20 of Set 9 | tessalit
# Processing Record 21 of Set 9 | coquimbo
# Processing Record 22 of Set 9 | laje
# Processing Record 23 of Set 9 | khandbari
# Processing Record 24 of Set 9 | maxixe
# Processing Record 25 of Set 9 | maiduguri
# Processing Record 26 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 27 of Set 9 | dehloran
# Processing Record 28 of Set 9 | severodvinsk
# Processing Record 29 of Set 9 | lichinga
# Processing Record 30 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 9 | braganca
# Processing Record 32 of Set 9 | rawson
# Processing Record 33 of Set 9 | puerto leguizamo
# Processing Record 34 of Set 9 | adrar
# Processing Record 35 of Set 9 | logrono
# Processing Record 36 of Set 9 | rio verde de mato grosso
# Processing Record 37 of Set 9 | korhogo
# Processing Record 38 of Set 9 | ardakan
# Processing Record 39 of Set 9 | cuamba
# Processing Record 40 of Set 9 | mahanoro
# Processing Record 41 of Set 9 | cap malheureux
# Processing Record 42 of Set 9 | astorga
# Processing Record 43 of Set 9 | takoradi
# Processing Record 44 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 9 | karwar
# Processing Record 46 of Set 9 | lethem
# Processing Record 47 of Set 9 | paamiut
# Processing Record 48 of Set 9 | ambilobe
# Processing Record 49 of Set 9 | labe
# Processing Record 50 of Set 9 | yambio
# Processing Record 1 of Set 10 | pedernales
# Processing Record 2 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 10 | ancud
# Processing Record 4 of Set 10 | magenta
# Processing Record 5 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 6 of Set 10 | muzhi
# Processing Record 7 of Set 10 | korla
# Processing Record 8 of Set 10 | plettenberg bay
# Processing Record 9 of Set 10 | envira
# Processing Record 10 of Set 10 | covington
# Processing Record 11 of Set 10 | meulaboh
# Processing Record 12 of Set 10 | campos sales
# Processing Record 13 of Set 10 | kismayo
# Processing Record 14 of Set 10 | lodja
# Processing Record 15 of Set 10 | guarapari
# Processing Record 16 of Set 10 | trinidad
# Processing Record 17 of Set 10 | cocobeach
# Processing Record 18 of Set 10 | carballo
# Processing Record 19 of Set 10 | yarmouth
# Processing Record 20 of Set 10 | kargasok
# Processing Record 21 of Set 10 | trairi
# Processing Record 22 of Set 10 | salta
# Processing Record 23 of Set 10 | tahta
# Processing Record 24 of Set 10 | sesheke
# Processing Record 25 of Set 10 | butterworth
# Processing Record 26 of Set 10 | porto velho
# Processing Record 27 of Set 10 | pangoa
# Processing Record 28 of Set 10 | tanhacu
# Processing Record 29 of Set 10 | chake chake
# Processing Record 30 of Set 10 | filingue
# Processing Record 31 of Set 10 | sagua la grande
# Processing Record 32 of Set 10 | lasa
# Processing Record 33 of Set 10 | sokolo
# Processing Record 34 of Set 10 | sisimiut
# Processing Record 35 of Set 10 | gao
# Processing Record 36 of Set 10 | kavaratti
# Processing Record 37 of Set 10 | teguldet
# Processing Record 38 of Set 10 | cap-aux-meules
# Processing Record 39 of Set 10 | srivardhan
# Processing Record 40 of Set 10 | cockburn town
# Processing Record 41 of Set 10 | ropczyce
# Processing Record 42 of Set 10 | chapais
# Processing Record 43 of Set 10 | padang
# Processing Record 44 of Set 10 | knysna
# Processing Record 45 of Set 10 | visani
# Processing Record 46 of Set 10 | saint anthony
# Processing Record 47 of Set 10 | grand-santi
# Processing Record 48 of Set 10 | sao borja
# Processing Record 49 of Set 10 | aulum
# Processing Record 50 of Set 10 | the valley
# Processing Record 1 of Set 11 | santa maria
# Processing Record 2 of Set 11 | murmino
# Processing Record 3 of Set 11 | graaff-reinet
# Processing Record 4 of Set 11 | itambe
# Processing Record 5 of Set 11 | ambad
# Processing Record 6 of Set 11 | digby
# Processing Record 7 of Set 11 | miraflores
# Processing Record 8 of Set 11 | enugu
# Processing Record 9 of Set 11 | grand gaube
# Processing Record 10 of Set 11 | muisne
# Processing Record 11 of Set 11 | bedford
# Processing Record 12 of Set 11 | tamandare
# Processing Record 13 of Set 11 | maceio
# Processing Record 14 of Set 11 | dunda
# Processing Record 15 of Set 11 | bam
# Processing Record 16 of Set 11 | santarem
# Processing Record 17 of Set 11 | marovoay
# Processing Record 18 of Set 11 | zambezi
# Processing Record 19 of Set 11 | rybachiy
# Processing Record 20 of Set 11 | staryy nadym
# Processing Record 21 of Set 11 | port-gentil
# Processing Record 22 of Set 11 | morondava
# Processing Record 23 of Set 11 | krasnyy kut
# Processing Record 24 of Set 11 | viedma
# Processing Record 25 of Set 11 | abadan
# Processing Record 26 of Set 11 | lastoursville
# Processing Record 27 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 28 of Set 11 | goderich
# Processing Record 29 of Set 11 | mezen
# Processing Record 30 of Set 11 | turukhansk
# Processing Record 31 of Set 11 | praia da vitoria
# Processing Record 32 of Set 11 | araripe
# Processing Record 33 of Set 11 | okakarara
# Processing Record 34 of Set 11 | yarkovo
# Processing Record 35 of Set 11 | mattawa
# Processing Record 36 of Set 11 | chingirlau
# Processing Record 37 of Set 11 | kedarnath
# City not found. Skipping...
# Processing Record 38 of Set 11 | gaspe
# Processing Record 39 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 40 of Set 11 | maragogi
# Processing Record 41 of Set 11 | charyshskoye
# Processing Record 42 of Set 11 | valparaiso
# Processing Record 43 of Set 11 | panvel
# Processing Record 44 of Set 11 | qandahar
# City not found. Skipping...
# Processing Record 45 of Set 11 | zabol
# Processing Record 46 of Set 11 | tarauaca
# Processing Record 47 of Set 11 | windham
# Processing Record 48 of Set 11 | teguise
# Processing Record 49 of Set 11 | gamba
# Processing Record 50 of Set 11 | porto da folha
# Processing Record 1 of Set 12 | dipkarpaz
# City not found. Skipping...
# Processing Record 2 of Set 12 | george
# Processing Record 3 of Set 12 | dunn
# Processing Record 4 of Set 12 | sibut
# Processing Record 5 of Set 12 | saint-georges
# Processing Record 6 of Set 12 | puerto colombia
# Processing Record 7 of Set 12 | dungarvan
# Processing Record 8 of Set 12 | bonavista
# Processing Record 9 of Set 12 | tucuma
# Processing Record 10 of Set 12 | stutterheim
# Processing Record 11 of Set 12 | winchester
# Processing Record 12 of Set 12 | iaciara
# Processing Record 13 of Set 12 | eskil
# Processing Record 14 of Set 12 | solenzo
# Processing Record 15 of Set 12 | cascais
# Processing Record 16 of Set 12 | calbuco
# Processing Record 17 of Set 12 | moissala
# Processing Record 18 of Set 12 | el carmen
# Processing Record 19 of Set 12 | mabaruma
# Processing Record 20 of Set 12 | bloemfontein
# Processing Record 21 of Set 12 | qom
# Processing Record 22 of Set 12 | polunochnoye
# Processing Record 23 of Set 12 | muros
# Processing Record 24 of Set 12 | villa carlos paz
# Processing Record 25 of Set 12 | kutum
# Processing Record 26 of Set 12 | pauini
# Processing Record 27 of Set 12 | marawi
# Processing Record 28 of Set 12 | zeerust
# Processing Record 29 of Set 12 | beloha
# Processing Record 30 of Set 12 | san andres
# Processing Record 31 of Set 12 | benjamin aceval
# Processing Record 32 of Set 12 | lagodekhi
# Processing Record 33 of Set 12 | tenenkou
# Processing Record 34 of Set 12 | sorland
# Processing Record 35 of Set 12 | paris
# Processing Record 36 of Set 12 | grindavik
# Processing Record 37 of Set 12 | balykshi
# Processing Record 38 of Set 12 | ufimskiy
# Processing Record 39 of Set 12 | bhunya
# Processing Record 40 of Set 12 | pokhara
# Processing Record 41 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 12 | sainte-suzanne
# Processing Record 43 of Set 12 | khairpur nathan shah
# Processing Record 44 of Set 12 | stornoway
# Processing Record 45 of Set 12 | siavonga
# Processing Record 46 of Set 12 | dutlwe
# Processing Record 47 of Set 12 | aksu
# Processing Record 48 of Set 12 | bolshaya glushitsa
# Processing Record 49 of Set 12 | abu kamal
# Processing Record 50 of Set 12 | chimbote
# Processing Record 1 of Set 13 | mozarlandia
# Processing Record 2 of Set 13 | ratnagiri
# Processing Record 3 of Set 13 | ballina
# Processing Record 4 of Set 13 | tanout
# Processing Record 5 of Set 13 | makinsk
# Processing Record 6 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 7 of Set 13 | mahajanga
# Processing Record 8 of Set 13 | camapua
# Processing Record 9 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 10 of Set 13 | bembereke
# Processing Record 11 of Set 13 | rosetta
# Processing Record 12 of Set 13 | rumonge
# Processing Record 13 of Set 13 | parabel
# Processing Record 14 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 15 of Set 13 | acoua
# Processing Record 16 of Set 13 | mwingi
# Processing Record 17 of Set 13 | puerto cabezas
# Processing Record 18 of Set 13 | hit
# Processing Record 19 of Set 13 | mikkeli
# Processing Record 20 of Set 13 | nueve de julio
# Processing Record 21 of Set 13 | lokosovo
# Processing Record 22 of Set 13 | concordia
# Processing Record 23 of Set 13 | bethanien
# Processing Record 24 of Set 13 | bolobo
# Processing Record 25 of Set 13 | a
# City not found. Skipping...
# Processing Record 26 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 27 of Set 13 | cabedelo
# Processing Record 28 of Set 13 | richards bay
# Processing Record 29 of Set 13 | finnsnes
# Processing Record 30 of Set 13 | port blair
# Processing Record 31 of Set 13 | birao
# Processing Record 32 of Set 13 | rangpo
# Processing Record 33 of Set 13 | talcahuano
# Processing Record 34 of Set 13 | businga
# Processing Record 35 of Set 13 | jidvei
# Processing Record 36 of Set 13 | mamallapuram
# Processing Record 37 of Set 13 | shelui
# Processing Record 38 of Set 13 | kichmengskiy gorodok
# Processing Record 39 of Set 13 | le vauclin
# Processing Record 40 of Set 13 | ust-tsilma
# Processing Record 41 of Set 13 | bodden town
# Processing Record 42 of Set 13 | kishni
# Processing Record 43 of Set 13 | mgandu
# Processing Record 44 of Set 13 | nowa ruda
# Processing Record 45 of Set 13 | tall kayf
# Processing Record 46 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 48 of Set 13 | werda
# Processing Record 49 of Set 13 | luena
# Processing Record 50 of Set 13 | oriximina
# Processing Record 1 of Set 14 | saint-joseph
# Processing Record 2 of Set 14 | irece
# Processing Record 3 of Set 14 | cochrane
# Processing Record 4 of Set 14 | kungsbacka
# Processing Record 5 of Set 14 | afonso bezerra
# Processing Record 6 of Set 14 | ulundurpettai
# City not found. Skipping...
# Processing Record 7 of Set 14 | bukene
# Processing Record 8 of Set 14 | beira
# Processing Record 9 of Set 14 | huambo
# Processing Record 10 of Set 14 | toamasina
# Processing Record 11 of Set 14 | road town
# Processing Record 12 of Set 14 | tocantinopolis
# City not found. Skipping...
# Processing Record 13 of Set 14 | monrovia
# Processing Record 14 of Set 14 | barcelos
# Processing Record 15 of Set 14 | surt
# Processing Record 16 of Set 14 | sabha
# Processing Record 17 of Set 14 | man
# Processing Record 18 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 19 of Set 14 | sandy bay
# Processing Record 20 of Set 14 | manoharpur
# Processing Record 21 of Set 14 | verkhnya syrovatka
# Processing Record 22 of Set 14 | kangaatsiaq
# Processing Record 23 of Set 14 | rastolita
# Processing Record 24 of Set 14 | bolshiye uki
# City not found. Skipping...
# Processing Record 25 of Set 14 | zheleznodorozhnyy
# Processing Record 26 of Set 14 | norden
# Processing Record 27 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 28 of Set 14 | oum hadjer
# Processing Record 29 of Set 14 | nicolas bravo
# Processing Record 30 of Set 14 | santiago del estero
# Processing Record 31 of Set 14 | nara
# Processing Record 32 of Set 14 | skjervoy
# Processing Record 33 of Set 14 | chimore
# Processing Record 34 of Set 14 | suksun
# Processing Record 35 of Set 14 | ahwa
# Processing Record 36 of Set 14 | havelock
# Processing Record 37 of Set 14 | la rioja
# Processing Record 38 of Set 14 | puri
# Processing Record 39 of Set 14 | baghdad
# Processing Record 40 of Set 14 | benguela
# Processing Record 41 of Set 14 | sladkovo
# Processing Record 42 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 14 | buta
# Processing Record 44 of Set 14 | rovaniemi
# Processing Record 45 of Set 14 | bulawayo
# Processing Record 46 of Set 14 | quebo
# Processing Record 47 of Set 14 | garachine
# Processing Record 48 of Set 14 | dwarka
# Processing Record 49 of Set 14 | ostersund
# Processing Record 50 of Set 14 | jericho
# Processing Record 1 of Set 15 | gonen
# Processing Record 2 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 15 | shache
# Processing Record 4 of Set 15 | lipari
# Processing Record 5 of Set 15 | culebra
# Processing Record 6 of Set 15 | namibe
# Processing Record 7 of Set 15 | gatun
# Processing Record 8 of Set 15 | rincon
# Processing Record 9 of Set 15 | impfondo
# Processing Record 10 of Set 15 | kathmandu
# Processing Record 11 of Set 15 | springfield
# Processing Record 12 of Set 15 | bhatkal
# Processing Record 13 of Set 15 | quatre cocos
# Processing Record 14 of Set 15 | koutiala
# Processing Record 15 of Set 15 | saurimo
# Processing Record 16 of Set 15 | goundam
# Processing Record 17 of Set 15 | kuytun
# Processing Record 18 of Set 15 | ouadda
# Processing Record 19 of Set 15 | tapes
# Processing Record 20 of Set 15 | pavilosta
# Processing Record 21 of Set 15 | warrington
# Processing Record 22 of Set 15 | mahon
# Processing Record 23 of Set 15 | bocanda
# Processing Record 24 of Set 15 | suluova
# Processing Record 25 of Set 15 | manta
# Processing Record 26 of Set 15 | uray
# Processing Record 27 of Set 15 | domodossola
# Processing Record 28 of Set 15 | rijnsburg
# Processing Record 29 of Set 15 | niamey
# Processing Record 30 of Set 15 | taywarah
# Processing Record 31 of Set 15 | lerwick
# Processing Record 32 of Set 15 | mao
# Processing Record 33 of Set 15 | hameenlinna
# Processing Record 34 of Set 15 | zavodoukovsk
# Processing Record 35 of Set 15 | sokoni
# Processing Record 36 of Set 15 | matara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Step 5. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Ust-Ishim  57.6935   71.1665      8.11        88         100        6.67
# 1  Walvis Bay -22.9575   14.5053     64.09        94         100       10.36
# 2       Rocha -34.4833  -54.3333     60.48        91          21        5.84
# 3    Hermanus -34.4187   19.2345     67.89        87           4       10.49
# 4      Kikwit  -5.0410   18.8162     71.87        77          99        1.59
# 5  Bredasdorp -34.5322   20.0403     66.27        85          12        6.49
# 6    Umm Lajj  25.0213   37.2685     60.98        43           0       10.54
# 7  Codrington -38.2667  141.9667     69.30        80          96       12.26
# 8      Nacala -14.5428   40.6728     78.21        84          59        1.36
# 9      Caxito  -8.5785   13.6643     74.53        96          98        2.17
#
#   Country                 Date
# 0      RU  2022-01-30 05:14:34
# 1      NA  2022-01-30 05:14:34
# 2      UY  2022-01-30 05:13:45
# 3      ZA  2022-01-30 05:14:35
# 4      CD  2022-01-30 05:14:35
# 5      ZA  2022-01-30 05:13:47
# 6      SA  2022-01-30 05:14:36
# 7      AU  2022-01-30 05:14:36
# 8      MZ  2022-01-30 05:14:37
# 9      AO  2022-01-30 05:14:38

# %%
# Step 6. Export the DataFrame as a CSV file.
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
